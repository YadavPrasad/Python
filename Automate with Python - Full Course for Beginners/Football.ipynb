# %%
pip install pandas,numpy

# %%
data = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/E0.csv")

# %%
data
# Out:
#     Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00  Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30     Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00     Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...         ...          ...   ...   ...  ..   ...
# 125  E0  30/11/2024  17:30    West Ham      Arsenal     2     5   A     2
# 126  E0  01/12/2024  13:30     Chelsea  Aston Villa     3     0   H     2
# 127  E0  01/12/2024  13:30  Man United      Everton     4     0   H     2
# 128  E0  01/12/2024  13:30   Tottenham       Fulham     1     1   D     0
# 129  E0  01/12/2024  16:00   Liverpool     Man City     2     0   H     1
#
#      HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# ...

# %%
data.rename(columns={"FTHG" : "Home Goal","FTAG" : "Away Goal"}, inplace=True)

# %%
data
# Out:
#     Div        Date   Time    HomeTeam     AwayTeam  Home Goal  Away Goal FTR  \
# 0    E0  16/08/2024  20:00  Man United       Fulham          1          0   H
# 1    E0  17/08/2024  12:30     Ipswich    Liverpool          0          2   A
# 2    E0  17/08/2024  15:00     Arsenal       Wolves          2          0   H
# 3    E0  17/08/2024  15:00     Everton     Brighton          0          3   A
# 4    E0  17/08/2024  15:00   Newcastle  Southampton          1          0   H
# ..   ..         ...    ...         ...          ...        ...        ...  ..
# 125  E0  30/11/2024  17:30    West Ham      Arsenal          2          5   A
# 126  E0  01/12/2024  13:30     Chelsea  Aston Villa          3          0   H
# 127  E0  01/12/2024  13:30  Man United      Everton          4          0   H
# 128  E0  01/12/2024  13:30   Tottenham       Fulham          1          1   D
# 129  E0  01/12/2024  16:00   Liverpool     Man City          2          0   H
#
# ...

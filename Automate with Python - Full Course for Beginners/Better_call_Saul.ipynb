# %%
import pandas as pd

# %%
data = pd.read_html("https://en.wikipedia.org/wiki/List_of_Better_Call_Saul_episodes")

# %%
data
# Out:
# [  Season Episodes              Originally aired
#    Season Episodes Episodes.1        First aired       Last aired
#  0      1       10         10   February 8, 2015    April 6, 2015
#  1      2       10         10  February 15, 2016   April 18, 2016
#  2      3       10         10     April 10, 2017    June 19, 2017
#  3      4       10         10     August 6, 2018  October 8, 2018
#  4      5       10         10  February 23, 2020   April 20, 2020
#  5      6       13          7     April 18, 2022     May 23, 2022
#  6      6       13          6      July 11, 2022  August 15, 2022,
#     No. overall  No. in season                  Title        Directed by  \
#  0            1              1                  "Uno"     Vince Gilligan
#  1            2              2                 "Mijo"  Michelle MacLaren
#  2            3              3                "Nacho"    Terry McDonough
#  3            4              4                 "Hero"      Colin Bucksey
# ...

# %%
len(data)
# Out:
# 24

# %%
data[0]
# Out:
#   Season Episodes              Originally aired
#   Season Episodes Episodes.1        First aired       Last aired
# 0      1       10         10   February 8, 2015    April 6, 2015
# 1      2       10         10  February 15, 2016   April 18, 2016
# 2      3       10         10     April 10, 2017    June 19, 2017
# 3      4       10         10     August 6, 2018  October 8, 2018
# 4      5       10         10  February 23, 2020   April 20, 2020
# 5      6       13          7     April 18, 2022     May 23, 2022
# 6      6       13          6      July 11, 2022  August 15, 2022
